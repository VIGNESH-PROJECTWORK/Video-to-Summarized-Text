# %%
! pip install pytube -q

# %%
from pytube import YouTube

# %%
VIDEO_URL = 'https://youtu.be/QvyTEx1wyOY?feature=shared'

# %%
yt = YouTube(VIDEO_URL)

# %%
yt.streams \
  .filter(only_audio = True, file_extension = 'mp4') \
  .first() \
  .download(filename = 'computerscience.mp4')
# Out:
# '/content/computerscience.mp4'

# %%
! ffmpeg -i computerscience.mp4 -acodec pcm_s16le -ar 16000 computerscience.wav
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'computerscience.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-01-06T00:06:03.000000Z
#   Duration: 00:05:34.65, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 1 kb/s (default)
#     Metadata:
#       creation_time   : 2024-01-06T00:06:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'computerscience.wav':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, stereo, s16, 512 kb/s (default)
#     Metadata:
#       creation_time   : 2024-01-06T00:06:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=   20915kB time=00:05:34.64 bitrate= 512.0kbits/s speed= 377x
# video:0kB audio:20915kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000364%

# %%
# !pip install huggingsound -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 838.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.

# %%
from huggingsound import SpeechRecognitionModel

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cpu'

# %%
model = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-english", device = device)
# Out:
# INFO:huggingsound.speech_recognition.model:Loading model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/262 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/300 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
import librosa

# %%
input_file = '/content/computerscience.wav'

# %%
print(librosa.get_samplerate(input_file))

# Stream over 30 seconds chunks rather than load the full file
stream = librosa.stream(
    input_file,
    block_length=30,
    frame_length=16000,
    hop_length=16000
)
# Out:
# 16000

# %%
import soundfile as sf

# %%
for i,speech in enumerate(stream):
  sf.write(f'{i}.wav', speech, 16000)

# %%
i
# Out:
# 11

# %%
audio_path =[]
for a in range(i+1):
  audio_path.append(f'/content/{a}.wav')

# %%
audio_path
# Out:
# ['/content/0.wav',
#  '/content/1.wav',
#  '/content/2.wav',
#  '/content/3.wav',
#  '/content/4.wav',
#  '/content/5.wav',
#  '/content/6.wav',
#  '/content/7.wav',
#  '/content/8.wav',
#  '/content/9.wav',
#  '/content/10.wav',
#  '/content/11.wav']

# %%
transcriptions = model.transcribe(audio_path)
# Out:
# 100%|██████████| 12/12 [07:55<00:00, 39.61s/it]

# %%
full_transcript = ' '

# %%
for item in transcriptions:
  full_transcript += ''.join(item['transcription'])

# %%
len(full_transcript)
# Out:
# 4356

# %%
from transformers import pipeline

# %%
summarization = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
summarized_text = summarization(full_transcript)

# %%
summarized_text[0]
# Out:
# " If you wanto build something cool you need to know programming right and there's so many things that you can do with computer science . The technology that were developing right now is can be used by your doctorithe next decaden you come into office and your sik the doctors mlecrynospitness cupi will put it into this magic machine which is the sequencer ."

# %%
num_iters = int(len(full_transcript)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + full_transcript[start:end])
  out = summarization(full_transcript[start:end], min_length = 5, max_length=20)
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

print(summarized_text)
# Out:
# input text
#  i think nineteenth century was about the industrial revolution about electricity about disrupting the agricultural society and making it more advanced the twentieth century was about physics and engineering to do more things easier in oeveryday life from refrigerators to washing machinesand the twenty-first century is definately the digital age is the internetevn if you anto become a race car driver or play baseball or build a house these things have been turned upside down by softwarethe letue spot is robot cus environmetevery single hour this lettus spot is seeing one-point-five-million plants and it's taking individual action on those plants we enable letus growers to have higher yields in their field by helping make it cheaper by helping produce food in a more sustainable way and at wasn't previously possible without computer science and technologyi've really fund job where we build polyvar which kind of combined all my favoritegramming as well as fasion  art and designand shoppin
# Summarized text
#  The twenty-first century is definately the digital age is the internetevn if
# input text
# ghalf the products you use these days are software products that you play with on hyourphone and so if you wanto build something cool you need to know programming right and there's so many things that you can do with computer science so you t work backwards from the cool things that you want to build and forget whats a lot of times computer programming part of tat right so you shuld learn to feelit's really exciting rightnow the technology that were developing right now iscan be used by your doctorithenext decaden you come into office and your sik the doctors mlecrynospitness cupi will put it into this magic machine which is the sequencer andin an hour i can tell you what you have or what's wrong with yourelooking for a newvirus for example will-downloaded data-base all the virusest are known and will search for heno art sequence of interest against a whole database of all virusesso you still need somebody to analyze the datathe computer is not smart rnuf yetoursoftware heltspeople's s
# Summarized text
#  Technology that were developing right now is can be used by your doctorithe next decaden
# input text
# ave energy and thereby reduced their carbon emissions todate we've saved over eight tarwadars which is the equivalent of about one-point-one million cars on the roadlinger forecasting linthere so many differentmers that go intoit would be impossible for hudown ndo all those calculations we need a computer model in order to forecast iti write sofphure which scanse images looking for bad images images that wenoredai wore very closely with organizations at the national center for missing children i know that the work that wegod has impected a life of peopinandi feel ver strongly about it because there's alotta social problems right now that communy lurish te se oftecge so lot upon empowering the people whoare their helping the world by giving them the tools to be able to competter that's something that we can do right now and its as available arehugethe merging of artan technology is getting more more significant now because computers and suffer such an integral part of our lives-datedpel
# Summarized text
#  The merging of artan technology is getting more more significant now because computers and suffer such
# input text
# e are realizing that it coun be quite creative to take this medium of computers and create creditable works of artin finding nimo when crushed and squirt and all he friends are plying through the eastustrolian current you're seeing images of waterfaing by- your seeing the colors on the back of the turtle youre seeing esides of efish all of those things are generated through math and computer programs that we write that we then give to the ars and they takecreate that fltwicket and mak it look beautiful and o the crox-evit is really about inventionit's about looking at the world being dissatisfied with things and questioning everythingfif i didn't learn how to programittwould belike ot learning how to read the feuture would just be closed to meif you're in the couting professionthere' so many things that you can do and you can prettymuch pick and choose the course you want o be inthink you canstart ing an in your college dorroom and youcan have a set of people who haven't built a big co
# Summarized text
#  Computer artists are realizing that it coun be quite creative to take this medium of computers and
# input text
# mpany before come together and built something that billion people usedaily it crazy to think about t and it's really it's humbling an its amazingreally its about e chansetorion ventions and then see it out there in the world and see people using  having fun having a better life because of something that wasn't there before that you put in the worlde ami
# Summarized text
#  "It's really it's humbling an its amazingreally its about e chans
# [' The twenty-first century is definately the digital age is the internetevn if', ' Technology that were developing right now is can be used by your doctorithe next decaden', ' The merging of artan technology is getting more more significant now because computers and suffer such', ' Computer artists are realizing that it coun be quite creative to take this medium of computers and', ' "It\'s really it\'s humbling an its amazingreally its about e chans']
